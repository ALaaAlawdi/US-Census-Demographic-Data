# %% [markdown]
# <a href="https://www.kaggle.com/code/alawdisoft/us-census-demographic-data?scriptVersionId=134254282" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # US Census Demographic Data

# %% [markdown]
# # This dataset expands on my earlier New York City Census Data dataset. It includes data from the entire country instead of just New York City.

# %% [markdown]
# # Loading Data

# %%
# importing library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data  = pd.read_csv('/kaggle/input/us-census-demographic-data/acs2015_census_tract_data.csv')
data.head()
# Out:
#    CensusTract    State   County  TotalPop   Men  Women  Hispanic  White  \
# 0   1001020100  Alabama  Autauga      1948   940   1008       0.9   87.4
# 1   1001020200  Alabama  Autauga      2156  1059   1097       0.8   40.4
# 2   1001020300  Alabama  Autauga      2968  1364   1604       0.0   74.5
# 3   1001020400  Alabama  Autauga      4423  2172   2251      10.5   82.8
# 4   1001020500  Alabama  Autauga     10763  4922   5841       0.7   68.5
#
#    Black  Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0    7.7     0.3  ...   0.5          2.3         2.1         25.0       943
# 1   53.3     0.0  ...   0.0          0.7         0.0         23.4       753
# 2   18.6     0.5  ...   0.0          0.0         2.5         19.6      1373
# 3    3.7     1.6  ...   0.0          2.6         1.6         25.3      1782
# 4   24.8     0.0  ...   0.0          0.6         0.9         24.8      5037
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0         77.1        18.3           4.6         0.0           5.4
# 1         77.0        16.9           6.1         0.0          13.3
# 2         64.1        23.6          12.3         0.0           6.2
# 3         75.7        21.2           3.1         0.0          10.8
# 4         67.1        27.6           5.3         0.0           4.2
#
# [5 rows x 37 columns]

# %%
data.shape
# Out:
# (74001, 37)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74001 entries, 0 to 74000
# Data columns (total 37 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CensusTract      74001 non-null  int64
#  1   State            74001 non-null  object
#  2   County           74001 non-null  object
#  3   TotalPop         74001 non-null  int64
#  4   Men              74001 non-null  int64
#  5   Women            74001 non-null  int64
#  6   Hispanic         73311 non-null  float64
#  7   White            73311 non-null  float64
#  8   Black            73311 non-null  float64
#  9   Native           73311 non-null  float64
#  10  Asian            73311 non-null  float64
#  11  Pacific          73311 non-null  float64
#  12  Citizen          74001 non-null  int64
#  13  Income           72901 non-null  float64
#  14  IncomeErr        72901 non-null  float64
#  15  IncomePerCap     73261 non-null  float64
#  16  IncomePerCapErr  73261 non-null  float64
#  17  Poverty          73166 non-null  float64
#  18  ChildPoverty     72883 non-null  float64
#  19  Professional     73194 non-null  float64
#  20  Service          73194 non-null  float64
#  21  Office           73194 non-null  float64
#  22  Construction     73194 non-null  float64
#  23  Production       73194 non-null  float64
#  24  Drive            73204 non-null  float64
#  25  Carpool          73204 non-null  float64
#  26  Transit          73204 non-null  float64
#  27  Walk             73204 non-null  float64
#  28  OtherTransp      73204 non-null  float64
#  29  WorkAtHome       73204 non-null  float64
#  30  MeanCommute      73052 non-null  float64
#  31  Employed         74001 non-null  int64
#  32  PrivateWork      73194 non-null  float64
#  33  PublicWork       73194 non-null  float64
#  34  SelfEmployed     73194 non-null  float64
#  35  FamilyWork       73194 non-null  float64
#  36  Unemployment     73199 non-null  float64
# dtypes: float64(29), int64(6), object(2)
# memory usage: 20.9+ MB

# %%
data.isnull().sum().sort_values()
# Out:
# CensusTract           0
# State                 0
# County                0
# TotalPop              0
# Men                   0
# Women                 0
# Employed              0
# Citizen               0
# Pacific             690
# Asian               690
# Black               690
# White               690
# Hispanic            690
# Native              690
# IncomePerCap        740
# IncomePerCapErr     740
# Carpool             797
# WorkAtHome          797
# OtherTransp         797
# Walk                797
# Transit             797
# Drive               797
# Unemployment        802
# Production          807
# Office              807
# Service             807
# Professional        807
# FamilyWork          807
# PrivateWork         807
# PublicWork          807
# SelfEmployed        807
# Construction        807
# Poverty             835
# MeanCommute         949
# IncomeErr          1100
# Income             1100
# ChildPoverty       1118
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [CensusTract, State, County, TotalPop, Men, Women, Hispanic, White, Black, Native, Asian, Pacific, Citizen, Income, IncomeErr, IncomePerCap, IncomePerCapErr, Poverty, ChildPoverty, Professional, Service, Office, Construction, Production, Drive, Carpool, Transit, Walk, OtherTransp, WorkAtHome, MeanCommute, Employed, PrivateWork, PublicWork, SelfEmployed, FamilyWork, Unemployment]
# Index: []
#
# [0 rows x 37 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72727 entries, 0 to 74000
# Data columns (total 37 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CensusTract      72727 non-null  int64
#  1   State            72727 non-null  object
#  2   County           72727 non-null  object
#  3   TotalPop         72727 non-null  int64
#  4   Men              72727 non-null  int64
#  5   Women            72727 non-null  int64
#  6   Hispanic         72727 non-null  float64
#  7   White            72727 non-null  float64
#  8   Black            72727 non-null  float64
#  9   Native           72727 non-null  float64
#  10  Asian            72727 non-null  float64
#  11  Pacific          72727 non-null  float64
#  12  Citizen          72727 non-null  int64
#  13  Income           72727 non-null  float64
#  14  IncomeErr        72727 non-null  float64
#  15  IncomePerCap     72727 non-null  float64
#  16  IncomePerCapErr  72727 non-null  float64
#  17  Poverty          72727 non-null  float64
#  18  ChildPoverty     72727 non-null  float64
#  19  Professional     72727 non-null  float64
#  20  Service          72727 non-null  float64
#  21  Office           72727 non-null  float64
#  22  Construction     72727 non-null  float64
#  23  Production       72727 non-null  float64
#  24  Drive            72727 non-null  float64
#  25  Carpool          72727 non-null  float64
#  26  Transit          72727 non-null  float64
#  27  Walk             72727 non-null  float64
#  28  OtherTransp      72727 non-null  float64
#  29  WorkAtHome       72727 non-null  float64
#  30  MeanCommute      72727 non-null  float64
#  31  Employed         72727 non-null  int64
#  32  PrivateWork      72727 non-null  float64
#  33  PublicWork       72727 non-null  float64
#  34  SelfEmployed     72727 non-null  float64
#  35  FamilyWork       72727 non-null  float64
#  36  Unemployment     72727 non-null  float64
# dtypes: float64(29), int64(6), object(2)
# memory usage: 21.1+ MB

# %%
data.shape
# Out:
# (72727, 37)

# %%
data.describe().T.style.background_gradient(cmap='YlOrRd')
# Out:
# <style type="text/css">
# #T_ec370_row0_col0, #T_ec370_row1_col0, #T_ec370_row1_col1, #T_ec370_row1_col2, #T_ec370_row1_col3, #T_ec370_row1_col4, #T_ec370_row1_col5, #T_ec370_row1_col6, #T_ec370_row1_col7, #T_ec370_row2_col0, #T_ec370_row2_col1, #T_ec370_row2_col2, #T_ec370_row2_col3, #T_ec370_row2_col4, #T_ec370_row2_col5, #T_ec370_row2_col6, #T_ec370_row2_col7, #T_ec370_row3_col0, #T_ec370_row3_col1, #T_ec370_row3_col2, #T_ec370_row3_col3, #T_ec370_row3_col4, #T_ec370_row3_col5, #T_ec370_row3_col6, #T_ec370_row3_col7, #T_ec370_row4_col0, #T_ec370_row4_col1, #T_ec370_row4_col2, #T_ec370_row4_col3, #T_ec370_row4_col4, #T_ec370_row4_col5, #T_ec370_row4_col6, #T_ec370_row4_col7, #T_ec370_row5_col0, #T_ec370_row5_col1, #T_ec370_row5_col2, #T_ec370_row5_col3, #T_ec370_row5_col4, #T_ec370_row5_col5, #T_ec370_row5_col6, #T_ec370_row5_col7, #T_ec370_row6_col0, #T_ec370_row6_col1, #T_ec370_row6_col2, #T_ec370_row6_col3, #T_ec370_row6_col4, #T_ec370_row6_col5, #T_ec370_row6_col6, #T_ec370_row6_col7, #T_ec370_row7_col0, #T_ec370_row7_col1, #T_ec370_row7_col2, #T_ec370_row7_col3, #T_ec370_row7_col4, #T_ec370_row7_col5, #T_ec370_row7_col6, #T_ec370_row7_col7, #T_ec370_row8_col0, #T_ec370_row8_col1, #T_ec370_row8_col2, #T_ec370_row8_col3, #T_ec370_row8_col4, #T_ec370_row8_col5, #T_ec370_row8_col6, #T_ec370_row8_col7, #T_ec370_row9_col0, #T_ec370_row9_col1, #T_ec370_row9_col2, #T_ec370_row9_col3, #T_ec370_row9_col4, #T_ec370_row9_col5, #T_ec370_row9_col6, #T_ec370_row9_col7, #T_ec370_row10_col0, #T_ec370_row10_col1, #T_ec370_row10_col2, #T_ec370_row10_col3, #T_ec370_row10_col4, #T_ec370_row10_col5, #T_ec370_row10_col6, #T_ec370_row10_col7, #T_ec370_row11_col0, #T_ec370_row11_col1, #T_ec370_row11_col2, #T_ec370_row11_col3, #T_ec370_row11_col4, #T_ec370_row11_col5, #T_ec370_row11_col6, #T_ec370_row11_col7, #T_ec370_row12_col0, #T_ec370_row12_col1, #T_ec370_row12_col2, #T_ec370_row12_col3, #T_ec370_row12_col4, #T_ec370_row12_col5, #T_ec370_row12_col6, #T_ec370_row12_col7, #T_ec370_row13_col0, #T_ec370_row13_col1, #T_ec370_row13_col2, #T_ec370_row13_col3, #T_ec370_row13_col4, #T_ec370_row13_col5, #T_ec370_row13_col6, #T_ec370_row13_col7, #T_ec370_row14_col0, #T_ec370_row14_col1, #T_ec370_row14_col2, #T_ec370_row14_col3, #T_ec370_row14_col4, #T_ec370_row14_col5, #T_ec370_row14_col6, #T_ec370_row14_col7, #T_ec370_row15_col0, #T_ec370_row15_col1, #T_ec370_row15_col2, #T_ec370_row15_col3, #T_ec370_row15_col4, #T_ec370_row15_col5, #T_ec370_row15_col6, #T_ec370_row15_col7, #T_ec370_row16_col0, #T_ec370_row16_col1, #T_ec370_row16_col2, #T_ec370_row16_col3, #T_ec370_row16_col4, #T_ec370_row16_col5, #T_ec370_row16_col6, #T_ec370_row16_col7, #T_ec370_row17_col0, #T_ec370_row17_col1, #T_ec370_row17_col2, #T_ec370_row17_col3, #T_ec370_row17_col4, #T_ec370_row17_col5, #T_ec370_row17_col6, #T_ec370_row17_col7, #T_ec370_row18_col0, #T_ec370_row18_col1, #T_ec370_row18_col2, #T_ec370_row18_col3, #T_ec370_row18_col4, #T_ec370_row18_col5, #T_ec370_row18_col6, #T_ec370_row18_col7, #T_ec370_row19_col0, #T_ec370_row19_col1, #T_ec370_row19_col2, #T_ec370_row19_col3, #T_ec370_row19_col4, #T_ec370_row19_col5, #T_ec370_row19_col6, #T_ec370_row19_col7, #T_ec370_row20_col0, #T_ec370_row20_col1, #T_ec370_row20_col2, #T_ec370_row20_col3, #T_ec370_row20_col4, #T_ec370_row20_col5, #T_ec370_row20_col6, #T_ec370_row20_col7, #T_ec370_row21_col0, #T_ec370_row21_col1, #T_ec370_row21_col2, #T_ec370_row21_col3, #T_ec370_row21_col4, #T_ec370_row21_col5, #T_ec370_row21_col6, #T_ec370_row21_col7, #T_ec370_row22_col0, #T_ec370_row22_col1, #T_ec370_row22_col2, #T_ec370_row22_col3, #T_ec370_row22_col4, #T_ec370_row22_col5, #T_ec370_row22_col6, #T_ec370_row22_col7, #T_ec370_row23_col0, #T_ec370_row23_col1, #T_ec370_row23_col2, #T_ec370_row23_col3, #T_ec370_row23_col4, #T_ec370_row23_col5, #T_ec370_row23_col6, #T_ec370_row23_col7, #T_ec370_row24_col0, #T_ec370_row24_col1, #T_ec370_row24_col2, #T_ec370_row24_col3, #T_ec370_row24_col4, #T_ec370_row24_col5, #T_ec370_row24_col6, #T_ec370_row24_col7, #T_ec370_row25_col0, ...
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_ec370_row0_col1, #T_ec370_row0_col2, #T_ec370_row0_col3, #T_ec370_row0_col4, #T_ec370_row0_col5, #T_ec370_row0_col6, #T_ec370_row0_col7 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ec370_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
#       <th class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec370_level0_row0" class="row_heading level0 row0" >CensusTract</th>
#       <td id="T_ec370_row0_col0" class="data row0 col0" >72727.000000</td>
#       <td id="T_ec370_row0_col1" class="data row0 col1" >28380476252.035515</td>
#       <td id="T_ec370_row0_col2" class="data row0 col2" >16440495735.945961</td>
#       <td id="T_ec370_row0_col3" class="data row0 col3" >1001020100.000000</td>
#       <td id="T_ec370_row0_col4" class="data row0 col4" >13051002450.000000</td>
#       <td id="T_ec370_row0_col5" class="data row0 col5" >28047003501.000000</td>
#       <td id="T_ec370_row0_col6" class="data row0 col6" >42003412551.000000</td>
#       <td id="T_ec370_row0_col7" class="data row0 col7" >72153750602.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ec370_level0_row1" class="row_heading level0 row1" >TotalPop</th>
#       <td id="T_ec370_row1_col0" class="data row1 col0" >72727.000000</td>
#       <td id="T_ec370_row1_col1" class="data row1 col1" >4383.554168</td>
#       <td id="T_ec370_row1_col2" class="data row1 col2" >2087.993162</td>
#       <td id="T_ec370_row1_col3" class="data row1 col3" >41.000000</td>
#       <td id="T_ec370_row1_col4" class="data row1 col4" >2944.000000</td>
#       <td id="T_ec370_row1_col5" class="data row1 col5" >4098.000000</td>
#       <td id="T_ec370_row1_col6" class="data row1 col6" >5467.500000</td>
#       <td id="T_ec370_row1_col7" class="data row1 col7" >53812.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ec370_level0_row2" class="row_heading level0 row2" >Men</th>
#       <t

# %%
data.describe()[1:].T.style.background_gradient(cmap='YlOrRd')
# Out:
# <style type="text/css">
# #T_92974_row0_col0, #T_92974_row0_col1, #T_92974_row0_col2, #T_92974_row0_col3, #T_92974_row0_col4, #T_92974_row0_col5, #T_92974_row0_col6 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_92974_row1_col0, #T_92974_row1_col1, #T_92974_row1_col2, #T_92974_row1_col3, #T_92974_row1_col4, #T_92974_row1_col5, #T_92974_row1_col6, #T_92974_row2_col0, #T_92974_row2_col1, #T_92974_row2_col2, #T_92974_row2_col3, #T_92974_row2_col4, #T_92974_row2_col5, #T_92974_row2_col6, #T_92974_row3_col0, #T_92974_row3_col1, #T_92974_row3_col2, #T_92974_row3_col3, #T_92974_row3_col4, #T_92974_row3_col5, #T_92974_row3_col6, #T_92974_row4_col0, #T_92974_row4_col1, #T_92974_row4_col2, #T_92974_row4_col3, #T_92974_row4_col4, #T_92974_row4_col5, #T_92974_row4_col6, #T_92974_row5_col0, #T_92974_row5_col1, #T_92974_row5_col2, #T_92974_row5_col3, #T_92974_row5_col4, #T_92974_row5_col5, #T_92974_row5_col6, #T_92974_row6_col0, #T_92974_row6_col1, #T_92974_row6_col2, #T_92974_row6_col3, #T_92974_row6_col4, #T_92974_row6_col5, #T_92974_row6_col6, #T_92974_row7_col0, #T_92974_row7_col1, #T_92974_row7_col2, #T_92974_row7_col3, #T_92974_row7_col4, #T_92974_row7_col5, #T_92974_row7_col6, #T_92974_row8_col0, #T_92974_row8_col1, #T_92974_row8_col2, #T_92974_row8_col3, #T_92974_row8_col4, #T_92974_row8_col5, #T_92974_row8_col6, #T_92974_row9_col0, #T_92974_row9_col1, #T_92974_row9_col2, #T_92974_row9_col3, #T_92974_row9_col4, #T_92974_row9_col5, #T_92974_row9_col6, #T_92974_row10_col0, #T_92974_row10_col1, #T_92974_row10_col2, #T_92974_row10_col3, #T_92974_row10_col4, #T_92974_row10_col5, #T_92974_row10_col6, #T_92974_row11_col0, #T_92974_row11_col1, #T_92974_row11_col2, #T_92974_row11_col3, #T_92974_row11_col4, #T_92974_row11_col5, #T_92974_row11_col6, #T_92974_row12_col0, #T_92974_row12_col1, #T_92974_row12_col2, #T_92974_row12_col3, #T_92974_row12_col4, #T_92974_row12_col5, #T_92974_row12_col6, #T_92974_row13_col0, #T_92974_row13_col1, #T_92974_row13_col2, #T_92974_row13_col3, #T_92974_row13_col4, #T_92974_row13_col5, #T_92974_row13_col6, #T_92974_row14_col0, #T_92974_row14_col1, #T_92974_row14_col2, #T_92974_row14_col3, #T_92974_row14_col4, #T_92974_row14_col5, #T_92974_row14_col6, #T_92974_row15_col0, #T_92974_row15_col1, #T_92974_row15_col2, #T_92974_row15_col3, #T_92974_row15_col4, #T_92974_row15_col5, #T_92974_row15_col6, #T_92974_row16_col0, #T_92974_row16_col1, #T_92974_row16_col2, #T_92974_row16_col3, #T_92974_row16_col4, #T_92974_row16_col5, #T_92974_row16_col6, #T_92974_row17_col0, #T_92974_row17_col1, #T_92974_row17_col2, #T_92974_row17_col3, #T_92974_row17_col4, #T_92974_row17_col5, #T_92974_row17_col6, #T_92974_row18_col0, #T_92974_row18_col1, #T_92974_row18_col2, #T_92974_row18_col3, #T_92974_row18_col4, #T_92974_row18_col5, #T_92974_row18_col6, #T_92974_row19_col0, #T_92974_row19_col1, #T_92974_row19_col2, #T_92974_row19_col3, #T_92974_row19_col4, #T_92974_row19_col5, #T_92974_row19_col6, #T_92974_row20_col0, #T_92974_row20_col1, #T_92974_row20_col2, #T_92974_row20_col3, #T_92974_row20_col4, #T_92974_row20_col5, #T_92974_row20_col6, #T_92974_row21_col0, #T_92974_row21_col1, #T_92974_row21_col2, #T_92974_row21_col3, #T_92974_row21_col4, #T_92974_row21_col5, #T_92974_row21_col6, #T_92974_row22_col0, #T_92974_row22_col1, #T_92974_row22_col2, #T_92974_row22_col3, #T_92974_row22_col4, #T_92974_row22_col5, #T_92974_row22_col6, #T_92974_row23_col0, #T_92974_row23_col1, #T_92974_row23_col2, #T_92974_row23_col3, #T_92974_row23_col4, #T_92974_row23_col5, #T_92974_row23_col6, #T_92974_row24_col0, #T_92974_row24_col1, #T_92974_row24_col2, #T_92974_row24_col3, #T_92974_row24_col4, #T_92974_row24_col5, #T_92974_row24_col6, #T_92974_row25_col0, #T_92974_row25_col1, #T_92974_row25_col2, #T_92974_row25_col3, #T_92974_row25_col4, #T_92974_row25_col5, #T_92974_row25_col6, #T_92974_row26_col0, #T_92974_row26_col1, #T_92974_row26_col2, #T_92974_row26_col3, #T_92974_row26_col4, #T_92974_row26_col5, #T_92974_row26_col6, #T_92974_row27_col0, #T_92974_row27_col1, #T_92974_row27_col2, #T_92974_row27_col3, #T_92974_row27_col4, #T_92974_row27_col5, #T_92974_row27_col6, #T_92974_row28_col0, #T_92974_row28_col1, #T_92974_row28_col2, #T_92974_row28_col3, #T_92974_r ...
#   background-color: #ffffcc;
#   color: #000000;
# }
# </style>
# <table id="T_92974_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mean</th>
#       <th class="col_heading level0 col1" >std</th>
#       <th class="col_heading level0 col2" >min</th>
#       <th class="col_heading level0 col3" >25%</th>
#       <th class="col_heading level0 col4" >50%</th>
#       <th class="col_heading level0 col5" >75%</th>
#       <th class="col_heading level0 col6" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92974_level0_row0" class="row_heading level0 row0" >CensusTract</th>
#       <td id="T_92974_row0_col0" class="data row0 col0" >28380476252.035515</td>
#       <td id="T_92974_row0_col1" class="data row0 col1" >16440495735.945961</td>
#       <td id="T_92974_row0_col2" class="data row0 col2" >1001020100.000000</td>
#       <td id="T_92974_row0_col3" class="data row0 col3" >13051002450.000000</td>
#       <td id="T_92974_row0_col4" class="data row0 col4" >28047003501.000000</td>
#       <td id="T_92974_row0_col5" class="data row0 col5" >42003412551.000000</td>
#       <td id="T_92974_row0_col6" class="data row0 col6" >72153750602.000000</td>
#     </tr>
#     <tr>
#       <th id="T_92974_level0_row1" class="row_heading level0 row1" >TotalPop</th>
#       <td id="T_92974_row1_col0" class="data row1 col0" >4383.554168</td>
#       <td id="T_92974_row1_col1" class="data row1 col1" >2087.993162</td>
#       <td id="T_92974_row1_col2" class="data row1 col2" >41.000000</td>
#       <td id="T_92974_row1_col3" class="data row1 col3" >2944.000000</td>
#       <td id="T_92974_row1_col4" class="data row1 col4" >4098.000000</td>
#       <td id="T_92974_row1_col5" class="data row1 col5" >5467.500000</td>
#       <td id="T_92974_row1_col6" class="data row1 col6" >53812.000000</td>
#     </tr>
#     <tr>
#       <th id="T_92974_level0_row2" class="row_heading level0 row2" >Men</th>
#       <td id="T_92974_row2_col0" class="data row2 col0" >2153.857536</td>
#       <td id="T_92974_row2_col1" class="data row2 col1" >1050.076773</td>
#       <td id="T_92974_row2_col2" class="data row2 col2" >16.000000</td>
#       <td id="T_92974_row2_col3" class="data row2 col3" >1434.000000</td>
#       <td id="T_92974_row2_col4" class="data row2 col4" >2002.000000</td>
#       <td id="T_92974_row2_col5" class="data row2 col5" >2685.500000</td>
#       <td id="T_92974_row2_col6" class="data row2 col6" >27962.000000</td>
#     </tr>
#     <tr>
#       <th id="T_92974_level0_row3" class="row_heading level0 row3" >Women</th>
#       <td id="T_92974_row3_col0" class="data row3 col0" >2229.696633</td>
#       <td id="T_92974_row3_col1" class="data row3 col1" >1072.694974</td>
#       <td id="T_92974_row3_col2" class="data row3 col2" >25.000000</td>
#       <td id="T_92974_row3_col3" class="data row3 col3" >1490.000000</td>
#       <td id="T_92974_row3_c

# %%
data.describe(percentiles=[.25,.5,.75,.90,.95,.99]).T.style.background_gradient(cmap='YlOrRd')
# Out:
# <style type="text/css">
# #T_3c1d5_row0_col0, #T_3c1d5_row1_col0, #T_3c1d5_row1_col1, #T_3c1d5_row1_col2, #T_3c1d5_row1_col3, #T_3c1d5_row1_col4, #T_3c1d5_row1_col5, #T_3c1d5_row1_col6, #T_3c1d5_row1_col7, #T_3c1d5_row1_col8, #T_3c1d5_row1_col9, #T_3c1d5_row1_col10, #T_3c1d5_row2_col0, #T_3c1d5_row2_col1, #T_3c1d5_row2_col2, #T_3c1d5_row2_col3, #T_3c1d5_row2_col4, #T_3c1d5_row2_col5, #T_3c1d5_row2_col6, #T_3c1d5_row2_col7, #T_3c1d5_row2_col8, #T_3c1d5_row2_col9, #T_3c1d5_row2_col10, #T_3c1d5_row3_col0, #T_3c1d5_row3_col1, #T_3c1d5_row3_col2, #T_3c1d5_row3_col3, #T_3c1d5_row3_col4, #T_3c1d5_row3_col5, #T_3c1d5_row3_col6, #T_3c1d5_row3_col7, #T_3c1d5_row3_col8, #T_3c1d5_row3_col9, #T_3c1d5_row3_col10, #T_3c1d5_row4_col0, #T_3c1d5_row4_col1, #T_3c1d5_row4_col2, #T_3c1d5_row4_col3, #T_3c1d5_row4_col4, #T_3c1d5_row4_col5, #T_3c1d5_row4_col6, #T_3c1d5_row4_col7, #T_3c1d5_row4_col8, #T_3c1d5_row4_col9, #T_3c1d5_row4_col10, #T_3c1d5_row5_col0, #T_3c1d5_row5_col1, #T_3c1d5_row5_col2, #T_3c1d5_row5_col3, #T_3c1d5_row5_col4, #T_3c1d5_row5_col5, #T_3c1d5_row5_col6, #T_3c1d5_row5_col7, #T_3c1d5_row5_col8, #T_3c1d5_row5_col9, #T_3c1d5_row5_col10, #T_3c1d5_row6_col0, #T_3c1d5_row6_col1, #T_3c1d5_row6_col2, #T_3c1d5_row6_col3, #T_3c1d5_row6_col4, #T_3c1d5_row6_col5, #T_3c1d5_row6_col6, #T_3c1d5_row6_col7, #T_3c1d5_row6_col8, #T_3c1d5_row6_col9, #T_3c1d5_row6_col10, #T_3c1d5_row7_col0, #T_3c1d5_row7_col1, #T_3c1d5_row7_col2, #T_3c1d5_row7_col3, #T_3c1d5_row7_col4, #T_3c1d5_row7_col5, #T_3c1d5_row7_col6, #T_3c1d5_row7_col7, #T_3c1d5_row7_col8, #T_3c1d5_row7_col9, #T_3c1d5_row7_col10, #T_3c1d5_row8_col0, #T_3c1d5_row8_col1, #T_3c1d5_row8_col2, #T_3c1d5_row8_col3, #T_3c1d5_row8_col4, #T_3c1d5_row8_col5, #T_3c1d5_row8_col6, #T_3c1d5_row8_col7, #T_3c1d5_row8_col8, #T_3c1d5_row8_col9, #T_3c1d5_row8_col10, #T_3c1d5_row9_col0, #T_3c1d5_row9_col1, #T_3c1d5_row9_col2, #T_3c1d5_row9_col3, #T_3c1d5_row9_col4, #T_3c1d5_row9_col5, #T_3c1d5_row9_col6, #T_3c1d5_row9_col7, #T_3c1d5_row9_col8, #T_3c1d5_row9_col9, #T_3c1d5_row9_col10, #T_3c1d5_row10_col0, #T_3c1d5_row10_col1, #T_3c1d5_row10_col2, #T_3c1d5_row10_col3, #T_3c1d5_row10_col4, #T_3c1d5_row10_col5, #T_3c1d5_row10_col6, #T_3c1d5_row10_col7, #T_3c1d5_row10_col8, #T_3c1d5_row10_col9, #T_3c1d5_row10_col10, #T_3c1d5_row11_col0, #T_3c1d5_row11_col1, #T_3c1d5_row11_col2, #T_3c1d5_row11_col3, #T_3c1d5_row11_col4, #T_3c1d5_row11_col5, #T_3c1d5_row11_col6, #T_3c1d5_row11_col7, #T_3c1d5_row11_col8, #T_3c1d5_row11_col9, #T_3c1d5_row11_col10, #T_3c1d5_row12_col0, #T_3c1d5_row12_col1, #T_3c1d5_row12_col2, #T_3c1d5_row12_col3, #T_3c1d5_row12_col4, #T_3c1d5_row12_col5, #T_3c1d5_row12_col6, #T_3c1d5_row12_col7, #T_3c1d5_row12_col8, #T_3c1d5_row12_col9, #T_3c1d5_row12_col10, #T_3c1d5_row13_col0, #T_3c1d5_row13_col1, #T_3c1d5_row13_col2, #T_3c1d5_row13_col3, #T_3c1d5_row13_col4, #T_3c1d5_row13_col5, #T_3c1d5_row13_col6, #T_3c1d5_row13_col7, #T_3c1d5_row13_col8, #T_3c1d5_row13_col9, #T_3c1d5_row13_col10, #T_3c1d5_row14_col0, #T_3c1d5_row14_col1, #T_3c1d5_row14_col2, #T_3c1d5_row14_col3, #T_3c1d5_row14_col4, #T_3c1d5_row14_col5, #T_3c1d5_row14_col6, #T_3c1d5_row14_col7, #T_3c1d5_row14_col8, #T_3c1d5_row14_col9, #T_3c1d5_row14_col10, #T_3c1d5_row15_col0, #T_3c1d5_row15_col1, #T_3c1d5_row15_col2, #T_3c1d5_row15_col3, #T_3c1d5_row15_col4, #T_3c1d5_row15_col5, #T_3c1d5_row15_col6, #T_3c1d5_row15_col7, #T_3c1d5_row15_col8, #T_3c1d5_row15_col9, #T_3c1d5_row15_col10, #T_3c1d5_row16_col0, #T_3c1d5_row16_col1, #T_3c1d5_row16_col2, #T_3c1d5_row16_col3, #T_3c1d5_row16_col4, #T_3c1d5_row16_col5, #T_3c1d5_row16_col6, #T_3c1d5_row16_col7, #T_3c1d5_row16_col8, #T_3c1d5_row16_col9, #T_3c1d5_row16_col10, #T_3c1d5_row17_col0, #T_3c1d5_row17_col1, #T_3c1d5_row17_col2, #T_3c1d5_row17_col3, #T_3c1d5_row17_col4, #T_3c1d5_row17_col5, #T_3c1d5_row17_col6, #T_3c1d5_row17_col7, #T_3c1d5_row17_col8, #T_3c1d5_row17_col9, #T_3c1d5_row17_col10, #T_3c1d5_row18_col0, #T_3c1d5_row18_col1, #T_3c1d5_row18_col2, #T_3c1d5_row18_col3, #T_3c1d5_row18_col4, #T_3c1d5_row18_col5, #T_3c1d5_ ...
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_3c1d5_row0_col1, #T_3c1d5_row0_col2, #T_3c1d5_row0_col3, #T_3c1d5_row0_col4, #T_3c1d5_row0_col5, #T_3c1d5_row0_col

# %%
data_new= data.drop(['CensusTract', 'State', 'County','IncomeErr','IncomePerCap','IncomePerCapErr'], axis=1)
data_new.head()
# Out:
#    TotalPop   Men  Women  Hispanic  White  Black  Native  Asian  Pacific  \
# 0      1948   940   1008       0.9   87.4    7.7     0.3    0.6      0.0
# 1      2156  1059   1097       0.8   40.4   53.3     0.0    2.3      0.0
# 2      2968  1364   1604       0.0   74.5   18.6     0.5    1.4      0.3
# 3      4423  2172   2251      10.5   82.8    3.7     1.6    0.0      0.0
# 4     10763  4922   5841       0.7   68.5   24.8     0.0    3.8      0.0
#
#    Citizen  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0     1503  ...   0.5          2.3         2.1         25.0       943
# 1     1662  ...   0.0          0.7         0.0         23.4       753
# 2     2335  ...   0.0          0.0         2.5         19.6      1373
# 3     3306  ...   0.0          2.6         1.6         25.3      1782
# 4     7666  ...   0.0          0.6         0.9         24.8      5037
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0         77.1        18.3           4.6         0.0           5.4
# 1         77.0        16.9           6.1         0.0          13.3
# 2         64.1        23.6          12.3         0.0           6.2
# 3         75.7        21.2           3.1         0.0          10.8
# 4         67.1        27.6           5.3         0.0           4.2
#
# [5 rows x 31 columns]

# %%
data[["TotalPop","Men","Women","Employed"]].describe().T.style.background_gradient(cmap='YlOrRd')
# Out:
# <style type="text/css">
# #T_d46ad_row0_col0, #T_d46ad_row1_col0, #T_d46ad_row1_col2, #T_d46ad_row2_col0, #T_d46ad_row3_col0, #T_d46ad_row3_col1, #T_d46ad_row3_col2, #T_d46ad_row3_col3, #T_d46ad_row3_col4, #T_d46ad_row3_col5, #T_d46ad_row3_col6, #T_d46ad_row3_col7 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_d46ad_row0_col1, #T_d46ad_row0_col2, #T_d46ad_row0_col3, #T_d46ad_row0_col4, #T_d46ad_row0_col5, #T_d46ad_row0_col6, #T_d46ad_row0_col7 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_d46ad_row1_col1 {
#   background-color: #fff7b9;
#   color: #000000;
# }
# #T_d46ad_row1_col3 {
#   background-color: #fede80;
#   color: #000000;
# }
# #T_d46ad_row1_col4, #T_d46ad_row2_col1 {
#   background-color: #fff2ac;
#   color: #000000;
# }
# #T_d46ad_row1_col5 {
#   background-color: #fff7b7;
#   color: #000000;
# }
# #T_d46ad_row1_col6 {
#   background-color: #fff9be;
#   color: #000000;
# }
# #T_d46ad_row1_col7 {
#   background-color: #ffec9f;
#   color: #000000;
# }
# #T_d46ad_row2_col2 {
#   background-color: #fffcc5;
#   color: #000000;
# }
# #T_d46ad_row2_col3 {
#   background-color: #fd8c3c;
#   color: #f1f1f1;
# }
# #T_d46ad_row2_col4 {
#   background-color: #ffeda0;
#   color: #000000;
# }
# #T_d46ad_row2_col5 {
#   background-color: #fff1a9;
#   color: #000000;
# }
# #T_d46ad_row2_col6 {
#   background-color: #fff4b2;
#   color: #000000;
# }
# #T_d46ad_row2_col7 {
#   background-color: #fff0a7;
#   color: #000000;
# }
# </style>
# <table id="T_d46ad_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
#       <th class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d46ad_level0_row0" class="row_heading level0 row0" >TotalPop</th>
#       <td id="T_d46ad_row0_col0" class="data row0 col0" >72727.000000</td>
#       <td id="T_d46ad_row0_col1" class="data row0 col1" >4383.554168</td>
#       <td id="T_d46ad_row0_col2" class="data row0 col2" >2087.993162</td>
#       <td id="T_d46ad_row0_col3" class="data row0 col3" >41.000000</td>
#       <td id="T_d46ad_row0_col4" class="data row0 col4" >2944.000000</td>
#       <td id="T_d46ad_row0_col5" class="data row0 col5" >4098.000000</td>
#       <td id="T_d46ad_row0_col6" class="data row0 col6" >5467.500000</td>
#       <td id="T_d46ad_row0_col7" class="data row0 col7" >53812.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d46ad_level0_row1" class="row_heading level0 row1" >Men</th>
#       <td id="T_d46ad_row1_col0" class="data row1 col0" >72727.000000</td>
#       <td id="T_d46ad_row1_col1" class="data row1 col1" >2153.857536</td>
#       <td id="T_d46ad_row1_col2" class="data row1 col2" >1050.076773</td>
#       <td id="T_d46ad_row1_col3" class="data row1 col3" >16.000000</td>
#       <td id="T_d46ad_row1_col4" class="data row1 col4" >1434.000000</td>
#       <td id="T_d46ad_row1_col5" class="data row1 col5" >2002.000000</td>
#       <td id="T_d46ad_row1_col6" class="data row1 col6" >2685.500000</td>
#       <td id="T_d46ad_row1_col7" class="data row1 col7" >27962.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d46ad_level0_row2" class="row_heading level0 row2" >Women</th>
#       <td id="T_d46ad_row2_col0" class="data row2 col0" >72727.000000</td>
#       <td id="T_d46ad_row2_col1" class="data row2 col1" >2229.696633</td>
#       <td id="T_d46ad_row2_col2" class="data row2 col2" >1072.694974</td>
#       <td id="T_d46ad_row2_col3" class="data row2 col3" >25.000000</td>
#       <td id="T_d46ad_row2_col4" class="data row2 col4" >1490.000000</td>
#       <td id="T_d46ad_row2_col5" class="data row2 col5" >2085.000000</td>
#       <td id="T_d46ad_row2_col6" class="data row2 col6" >2788.000000</td>
#       <td id="T_d46ad_row2_col7" class="data row2 col7" >27250.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d46ad_level0_row3" class="row_heading level0 row3" >Employed</th>
#       <td id="T_d46ad_row3_col0" class="data row3 col0" >72727.000000</td>
#       <td id="T_d46ad_row3_col1" class="data row3 col1" >2015.351864</td>
#       <td id="T_d46ad_row3_col2" class="data row3 col2" >1053.964941</td>
#       <td id="T_d46ad_row3_col3" class="data row3 col3" >9.000000</td>
#       <td id="T_d46ad_row3_col4" class="data row3 col4" >1279.000000</td>
#       <td id="T_d46ad_row3_col5" class="data row3 col5" >1866.000000</td>
#       <td id="T_d46ad_row3_col6" class="data row3 col6" >2568.000000</td>
#       <td id="T_d46ad_row3_col7" class="data row3 col7" >24075.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# TotalPop always is the sum of Men and Women population, let's drop it:
data_new= data_new.drop(['TotalPop'], axis=1)
data_new.head()
# Out:
#     Men  Women  Hispanic  White  Black  Native  Asian  Pacific  Citizen  \
# 0   940   1008       0.9   87.4    7.7     0.3    0.6      0.0     1503
# 1  1059   1097       0.8   40.4   53.3     0.0    2.3      0.0     1662
# 2  1364   1604       0.0   74.5   18.6     0.5    1.4      0.3     2335
# 3  2172   2251      10.5   82.8    3.7     1.6    0.0      0.0     3306
# 4  4922   5841       0.7   68.5   24.8     0.0    3.8      0.0     7666
#
#     Income  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0  61838.0  ...   0.5          2.3         2.1         25.0       943
# 1  32303.0  ...   0.0          0.7         0.0         23.4       753
# 2  44922.0  ...   0.0          0.0         2.5         19.6      1373
# 3  54329.0  ...   0.0          2.6         1.6         25.3      1782
# 4  51965.0  ...   0.0          0.6         0.9         24.8      5037
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0         77.1        18.3           4.6         0.0           5.4
# 1         77.0        16.9           6.1         0.0          13.3
# 2         64.1        23.6          12.3         0.0           6.2
# 3         75.7        21.2           3.1         0.0          10.8
# 4         67.1        27.6           5.3         0.0           4.2
#
# [5 rows x 30 columns]

# %%
convert = ['Men','Women','Employed']
data_new[convert] = data_new[convert].div(data["TotalPop"], axis="index")*100

# %%
data_new['RaceOther']= data_new['Asian'] + data_new['Pacific']+ data_new['Native']
data_new=data_new.drop(['Asian', 'Pacific','Native'], axis=1)

# %%
data_new = data_new.loc[data_new['Income'] > 0]

# %%
data_new.head()
# Out:
#          Men      Women  Hispanic  White  Black  Citizen   Income  Poverty  \
# 0  48.254620  51.745380       0.9   87.4    7.7     1503  61838.0      8.1
# 1  49.118738  50.881262       0.8   40.4   53.3     1662  32303.0     25.5
# 2  45.956873  54.043127       0.0   74.5   18.6     2335  44922.0     12.7
# 3  49.106941  50.893059      10.5   82.8    3.7     3306  54329.0      2.1
# 4  45.730744  54.269256       0.7   68.5   24.8     7666  51965.0     11.4
#
#    ChildPoverty  Professional  ...  OtherTransp  WorkAtHome  MeanCommute  \
# 0           8.4          34.7  ...          2.3         2.1         25.0
# 1          40.3          22.3  ...          0.7         0.0         23.4
# 2          19.7          31.4  ...          0.0         2.5         19.6
# 3           1.6          27.0  ...          2.6         1.6         25.3
# 4          17.5          49.6  ...          0.6         0.9         24.8
#
#     Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment  \
# 0  48.408624         77.1        18.3           4.6         0.0           5.4
# 1  34.925788         77.0        16.9           6.1         0.0          13.3
# 2  46.260108         64.1        23.6          12.3         0.0           6.2
# 3  40.289396         75.7        21.2           3.1         0.0          10.8
# 4  46.799220         67.1        27.6           5.3         0.0           4.2
#
#    RaceOther
# 0        0.9
# 1        2.3
# 2        2.2
# 3        1.6
# 4        3.8
#
# [5 rows x 28 columns]

# %%
#to move the target column to the last
cols = list(data_new.columns.values)
cols.pop(cols.index('Income')) 
data_new = data_new[cols+['Income']]
data_new.head()
# Out:
#          Men      Women  Hispanic  White  Black  Citizen  Poverty  \
# 0  48.254620  51.745380       0.9   87.4    7.7     1503      8.1
# 1  49.118738  50.881262       0.8   40.4   53.3     1662     25.5
# 2  45.956873  54.043127       0.0   74.5   18.6     2335     12.7
# 3  49.106941  50.893059      10.5   82.8    3.7     3306      2.1
# 4  45.730744  54.269256       0.7   68.5   24.8     7666     11.4
#
#    ChildPoverty  Professional  Service  ...  WorkAtHome  MeanCommute  \
# 0           8.4          34.7     17.0  ...         2.1         25.0
# 1          40.3          22.3     24.7  ...         0.0         23.4
# 2          19.7          31.4     24.9  ...         2.5         19.6
# 3           1.6          27.0     20.8  ...         1.6         25.3
# 4          17.5          49.6     14.2  ...         0.9         24.8
#
#     Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment  \
# 0  48.408624         77.1        18.3           4.6         0.0           5.4
# 1  34.925788         77.0        16.9           6.1         0.0          13.3
# 2  46.260108         64.1        23.6          12.3         0.0           6.2
# 3  40.289396         75.7        21.2           3.1         0.0          10.8
# 4  46.799220         67.1        27.6           5.3         0.0           4.2
#
#    RaceOther   Income
# 0        0.9  61838.0
# 1        2.3  32303.0
# 2        2.2  44922.0
# 3        1.6  54329.0
# 4        3.8  51965.0
#
# [5 rows x 28 columns]

# %%
Categorical=data_new.select_dtypes(include='object').columns.tolist()
Categorical
# Out:
# []

# %%
Numerical=data_new.select_dtypes(exclude='object').columns.tolist()
Numerical
# Out:
# ['Men',
#  'Women',
#  'Hispanic',
#  'White',
#  'Black',
#  'Citizen',
#  'Poverty',
#  'ChildPoverty',
#  'Professional',
#  'Service',
#  'Office',
#  'Construction',
#  'Production',
#  'Drive',
#  'Carpool',
#  'Transit',
#  'Walk',
#  'OtherTransp',
#  'WorkAtHome',
#  'MeanCommute',
#  'Employed',
#  'PrivateWork',
#  'PublicWork',
#  'SelfEmployed',
#  'FamilyWork',
#  'Unemployment',
#  'RaceOther',
#  'Income']

# %%
data.describe(percentiles=[.25,.5,.75,.90,.95,.99])
# Out:
#         CensusTract      TotalPop           Men         Women      Hispanic  \
# count  7.272700e+04  72727.000000  72727.000000  72727.000000  72727.000000
# mean   2.838048e+10   4383.554168   2153.857536   2229.696633     16.872317
# std    1.644050e+10   2087.993162   1050.076773   1072.694974     22.944267
# min    1.001020e+09     41.000000     16.000000     25.000000      0.000000
# 25%    1.305100e+10   2944.000000   1434.000000   1490.000000      2.400000
# 50%    2.804700e+10   4098.000000   2002.000000   2085.000000      7.000000
# 75%    4.200341e+10   5467.500000   2685.500000   2788.000000     20.500000
# 90%    4.845995e+10   6908.000000   3425.000000   3524.000000     51.100000
# 95%    5.303303e+10   7876.700000   3928.000000   4028.000000     73.800000
# 99%    7.202103e+10  10728.740000   5404.740000   5482.740000     98.800000
# max    7.215375e+10  53812.000000  27962.000000  27250.000000    100.000000
#
#               White         Black        Native         Asian       Pacific  \
# count  72727.000000  72727.000000  72727.000000  72727.000000  72727.000000
# mean      62.064004     13.239472      0.722961      4.589613      0.143765
# std       30.675537     21.750092      4.462781      8.793507      1.025069
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       39.400000      0.700000      0.000000      0.200000      0.000000
# 50%       71.400000      3.700000      0.000000      1.400000      0.000000
# 75%       88.400000     14.300000      0.400000      4.800000      0.000000
# 90%       95.000000     42.000000      1.200000     12.300000      0.200000
# 95%       96.800000     70.300000      2.200000     20.300000      0.600000
# 99%       98.800000     94.800000     10.000000     47.174000      3.100000
# max      100.000000    100.000000    100.000000     91.300000     84.700000
#
#        ...          Walk   OtherTransp    WorkAtHome   MeanCommute  \
# count  ...  72727.000000  72727.000000  72727.000000  72727.000000
# mean   ...      3.008150      1.880372      4.322362     25.690046
# std    ...      5.322402      2.511029      3.654009      6.935272
# min    ...      0.000000      0.000000      0.000000      4.900000
# 25%    ...      0.400000      0.400000      1.800000     20.900000
# 50%    ...      1.400000      1.200000      3.500000     25.000000
# 75%    ...      3.400000      2.500000      5.900000     29.800000
# 90%    ...      7.000000      4.500000      8.800000     34.700000
# 95%    ...     10.900000      6.300000     10.900000     38.200000
# 99%    ...     28.200000     11.800000     16.300000     45.600000
# max    ...     90.900000     58.600000     90.600000     70.500000
#
#            Employed   PrivateWork    PublicWork  SelfEmployed    FamilyWork  \
# count  72727.000000  72727.000000  72727.000000  72727.000000  72727.000000
# mean    2015.351864     79.006662     14.599978      6.223640      0.170106
# std     1053.964941      8.135376      7.369653      3.840184      0.457256
# min        9.000000     14.100000      0.000000      0.000000      0.000000
# 25%     1279.000000     74.600000      9.600000      3.600000      0.000000
# 50%     1866.000000     80.100000     13.400000      5.500000      0.000000
# 75%     2568.000000     84.600000     18.200000      8.100000      0.000000
# 90%     3316.000000     88.100000     23.700000     11.100000      0.600000
# 95%     3837.000000     90.100000     27.800000     13.400000      1.000000
# 99%     5162.740000     93.400000     38.400000     18.900000      2.100000
# max    24075.000000    100.000000     85.700000     48.600000     26.500000
#
#        Unemployment
# count  72727.000000
# mean       9.003846
# std        5.798221
# min        0.000000
# 25%        5.100000
# 50%        7.700000
# 75%       11.300000
# 90%       16.300000
# 95%       20.200000
# 99%       29.874000
# max       68.800000
#
# [11 rows x 35 columns]

# %% [markdown]
# # visualization

# %%
# correlation matrix
plt.figure(figsize=(25,8))
sns.heatmap(data_new.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # unique_values

# %%
unique_values=[None]*len(Numerical)
for i, p in enumerate(Numerical):
    unique_values[i]= len(data_new[p].unique())
    print('unique_values',p," =", unique_values[i])
# Out:
# unique_values Men  = 68348
# unique_values Women  = 68348
# unique_values Hispanic  = 1001
# unique_values White  = 1001
# unique_values Black  = 1000
# unique_values Citizen  = 7140
# unique_values Poverty  = 815
# unique_values ChildPoverty  = 960
# unique_values Professional  = 864
# unique_values Service  = 589
# unique_values Office  = 470
# unique_values Construction  = 481
# unique_values Production  = 491
# unique_values Drive  = 977
# unique_values Carpool  = 413
# unique_values Transit  = 831
# unique_values Walk  = 565
# unique_values OtherTransp  = 286
# unique_values WorkAtHome  = 338
# unique_values MeanCommute  = 521
# unique_values Employed  = 70623
# unique_values PrivateWork  = 676
# unique_values PublicWork  = 631
# unique_values SelfEmployed  = 315
# unique_values FamilyWork  = 73
# unique_values Unemployment  = 468
# unique_values RaceOther  = 1390
# unique_values Income  = 41503

# %% [markdown]
# # Checking Outliers

# %%
for i in Numerical:
    plt.figure()
    plt.tight_layout()
    
    plt.figure(figsize=(8,6))
    sns.boxenplot(x=data_new[i],palette='Blues')
    plt.show()

# %%
number_of_outliers=[None]*len(Numerical)
q75=[None]*len(Numerical)
q25=[None]*len(Numerical)
IQR=[None]*len(Numerical)


for i, p in enumerate(Numerical):
    q75[i], q25[i]= np.percentile(data_new[p],[95,5])
    IQR[i]= q75[i]- q25[i]
    #number_of_outliers[i]=df[~((df[p] < (q75[i] + 1.5 * IQR[i])) & (df[p] > (q25[i]-1.5*IQR[i])))].shape[0]
    number_of_outliers[i]=len((np.where((data_new[p] > (q75[i] + 1.5 * IQR[i])) | (data_new[p]< (q25[i] - 1.5 * IQR[i])))[0]))
    
    print('outliers of',p," =", number_of_outliers[i])
    
    print("*"*40)
# Out:
# outliers of Men  = 162
# ****************************************
# outliers of Women  = 162
# ****************************************
# outliers of Hispanic  = 0
# ****************************************
# outliers of White  = 0
# ****************************************
# outliers of Black  = 0
# ****************************************
# outliers of Citizen  = 67
# ****************************************
# outliers of Poverty  = 0
# ****************************************
# outliers of ChildPoverty  = 0
# ****************************************
# outliers of Professional  = 0
# ****************************************
# outliers of Service  = 1
# ****************************************
# outliers of Office  = 1
# ****************************************
# outliers of Construction  = 48
# ****************************************
# outliers of Production  = 0
# ****************************************
# outliers of Drive  = 0
# ****************************************
# outliers of Carpool  = 19
# ****************************************
# outliers of Transit  = 295
# ****************************************
# outliers of Walk  = 778
# ****************************************
# outliers of OtherTransp  = 257
# ****************************************
# outliers of WorkAtHome  = 82
# ****************************************
# outliers of MeanCommute  = 0
# ****************************************
# outliers of Employed  = 0
# ****************************************
# outliers of PrivateWork  = 22
# ****************************************
# outliers of PublicWork  = 73
# ****************************************
# outliers of SelfEmployed  = 20
# ****************************************
# outliers of FamilyWork  = 398
# ****************************************
# outliers of Unemployment  = 37
# ****************************************
# outliers of RaceOther  = 640
# ****************************************
# outliers of Income  = 4
# ****************************************

# %%
#Find the outliers records which fall with +/- 5% boundaries 

Q1 = data_new.quantile(0.05)
Q3 = data_new.quantile(0.95)
IQR = Q3 - Q1

print("Number of outliers for entire dataset = ", len(data_new[((data_new < (Q1 - 1.5 * IQR)) |(data_new > (Q3 + 1.5 * IQR))).any(axis=1)]))
# Out:
# Number of outliers for entire dataset =  2686

# %% [markdown]
# ## Distrbution of data point

# %%
for i in Numerical:
    ax=sns.histplot(x= data_new[i], color='teal', bins= 15, kde= True, palette= 'twilight')
    ax.set(xlabel= i , ylabel= 'Frequency')
    
    plt.tight_layout()
    plt.show()

# %%
# Create a list of float colums to check for skewing
mask = data_new.dtypes == np.float
float_cols = data_new.columns[mask]

skew_limit = 1.8 # define a limit above which we will log transform
skew_vals = data_new[float_cols].skew()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
# Showing the skewed columns
skew_cols = (skew_vals
             .sort_values(ascending=False)
             .to_frame()
             .rename(columns={0:'Skew'})
             .query('abs(Skew) > {}'.format(skew_limit)))

skew_cols
# Out:
#                   Skew
# FamilyWork    7.299289
# Walk          5.021101
# OtherTransp   4.165444
# RaceOther     4.134991
# Transit       3.628001
# WorkAtHome    2.597884
# Black         2.317443
# Hispanic      1.997605
# Unemployment  1.817818
# Drive        -2.192021

# %%
# Let's look at what happens to one of these features, when we apply np.log1p visually.

# Choose a field
field = "Unemployment"

# Create two "subplots" and a "figure" using matplotlib
fig, (ax_before, ax_after) = plt.subplots(1, 2, figsize=(10, 5))

# Create a histogram on the "ax_before" subplot
data_new[field].hist(ax=ax_before)

# Apply a log transformation (numpy syntax) to this column
data_new[field].apply(np.log1p).hist(ax=ax_after)

# Formatting of titles etc. for each subplot
ax_before.set(title='before np.log1p', ylabel='frequency', xlabel='value')
ax_after.set(title='after np.log1p', ylabel='frequency', xlabel='value')
fig.suptitle('Field "{}"'.format(field));

# %%
# Perform the skew transformation:

for col in skew_cols.index.values:
    if col == "state":
        continue
    data_new[col] = data_new[col].apply(np.log1p)

# %% [markdown]
# # Splitting the data into train and test sets¶

# %%
X= data_new.drop(["Income"], axis=1)
y= data_new.Income

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2, random_state=0)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((58181, 27), (14546, 27), (58181,), (14546,))

# %% [markdown]
# # PCA

# %%
from sklearn.preprocessing import StandardScaler
# get the features and label from the original dataframe

# performing standardization
sc = StandardScaler()
X_train= sc.fit_transform(X_train)
X_test= sc.fit_transform(X_test)

# %%
from sklearn.decomposition import PCA
components = 17
pca = PCA(n_components = components)
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

# %%
X_train.shape
# Out:
# (58181, 17)

# %%
# plot a scree plot
components = len(pca.explained_variance_ratio_) \
    if components is None else components
plt.plot(range(1,components+1), 
         np.cumsum(pca.explained_variance_ratio_ * 100))
plt.xlabel("Number of components")
plt.ylabel("Explained variance (%)")
# Out:
# Text(0, 0.5, 'Explained variance (%)')

# %%
# from sklearn.decomposition import PCA
# pca = PCA(n_components = 0.95)
# X_train = pca.fit_transform(X_train)
# X_test = pca.transform(X_test)
# print("Cumulative Variances (Percentage):")
# print(np.cumsum(pca.explained_variance_ratio_ * 100))
# components = len(pca.explained_variance_ratio_)
# print(f'Number of components: {components}')
# # Make the scree plot
# plt.plot(range(1, components + 1), np.cumsum(pca.explained_variance_ratio_ * 100))
# plt.xlabel("Number of components")
# plt.ylabel("Explained variance (%)")

# %%
# from sklearn.decomposition import PCA
# pca = PCA(n_components = 0.90)
# X_train_1 = pca.fit_transform(X_train)
# X_test_1 = pca.transform(X_test)
# print("Cumulative Variances (Percentage):")
# print(np.cumsum(pca.explained_variance_ratio_ * 100))
# components = len(pca.explained_variance_ratio_)
# print(f'Number of components: {components}')
# # Make the scree plot
# plt.plot(range(1, components + 1), np.cumsum(pca.explained_variance_ratio_ * 100))
# plt.xlabel("Number of components")
# plt.ylabel("Explained variance (%)")

# %%
# from sklearn.decomposition import PCA
# pca = PCA(n_components = 0.85)
# pca.fit(X_train)
# print("Cumulative Variances (Percentage):")
# print(np.cumsum(pca.explained_variance_ratio_ * 100))
# components = len(pca.explained_variance_ratio_)
# print(f'Number of components: {components}')
# # Make the scree plot
# plt.plot(range(1, components + 1), np.cumsum(pca.explained_variance_ratio_ * 100))
# plt.xlabel("Number of components")
# plt.ylabel("Explained variance (%)")

# %% [markdown]
# # model

# %% [markdown]
# # LinearRegression

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred =regressor.predict(X_test)

# %%
from sklearn import metrics
# print("\tMean absolute error:",metrics.mean_absolute_error(y_test, y_pred))
print("\tR2 score:",metrics.r2_score(y_test, y_pred))
# Out:
# 	R2 score: 0.7033367432245561

# %%
plt.figure()
ax1 = sns.distplot(y_test, hist=False, color="r", label="Actual Value")
sns.distplot(y_pred, hist=False, color="b", label="Fitted Values" , ax=ax1)

plt.title('Actual vs Fitted Values')
plt.xlabel('Income')

plt.show()
plt.close()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor( random_state = 0)
regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
y_pred =regressor.predict(X_test)

# %%
from sklearn import metrics
# print("\tMean absolute error:",metrics.mean_absolute_error(y_test, y_pred))
print("\tR2 score:",metrics.r2_score(y_test, y_pred))
# Out:
# 	R2 score: 0.6148504043069327

# %%
plt.figure()
ax1 = sns.distplot(y_test, hist=False, color="r", label="Actual Value")
sns.distplot(y_pred, hist=False, color="b", label="Fitted Values" , ax=ax1)

plt.title('Actual vs Fitted Values')
plt.xlabel('Income')

plt.show()
plt.close()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
y_pred =regressor.predict(X_test)

# %%
from sklearn import metrics
# print("\tMean absolute error:",metrics.mean_absolute_error(y_test, y_pred))
print("\tR2 score:",metrics.r2_score(y_test, y_pred))
# Out:
# 	R2 score: 0.8003677110424212

# %%
plt.figure()
ax1 = sns.distplot(y_test, hist=False, color="r", label="Actual Value")
sns.distplot(y_pred, hist=False, color="b", label="Fitted Values" , ax=ax1)

plt.title('Actual vs Fitted Values')
plt.xlabel('Income')

plt.show()
plt.close()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # GridSearch

# %%
from sklearn.model_selection import GridSearchCV

# %%
RF_param_grid = { 
    'n_estimators': [200, 300, 400],
    'max_features': ['auto','log2'],
    'max_depth' : [10,20,30]}
RF_GridCV = GridSearchCV(RandomForestRegressor(), RF_param_grid, cv=5, n_jobs= -1)
RF_GridCV.fit(X_train,y_train)  
print(RF_GridCV.best_params_)    
print(RF_GridCV.best_score_)
# Out:
# /opt/conda/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py:691: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# {'max_depth': 30, 'max_features': 'log2', 'n_estimators': 400}
# 0.8183452501836834

# %%
results_RF= pd.DataFrame(RF_GridCV.cv_results_)
results_RF
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      163.889702      0.273536         0.398875        0.006155
# 1      245.032503      0.317677         0.605679        0.007936
# 2      328.009489      1.000049         0.805491        0.022881
# 3       43.345094      0.242702         0.354370        0.005801
# 4       65.201924      0.172986         0.531401        0.010038
# 5       87.404107      0.405630         0.712906        0.016947
# 6      239.653102      0.636005         1.071315        0.010552
# 7      360.034979      1.372989         1.624419        0.023897
# 8      482.305970      1.587483         2.219877        0.045843
# 9       67.082506      0.165329         1.056126        0.004675
# 10     100.830831      0.243701         1.736167        0.253565
# 11     134.178172      0.419320         2.218857        0.256031
# 12     249.886909      0.369394         1.250194        0.021684
# 13     374.003461      0.867362         1.950987        0.199616
# 14     500.877647      1.034046         2.539133        0.072168
# 15      71.649917      0.402558         1.301358        0.070553
# 16     106.945901      0.574306         1.980088        0.150766
# 17     132.066003     12.742011         2.346384        0.194375
#
#    param_max_depth param_max_features param_n_estimators  \
# 0               10               auto                200
# 1               10               auto                300
# 2               10               auto                400
# 3               10               log2                200
# 4               10               log2                300
# 5               10               log2                400
# 6               20               auto                200
# 7               20               auto                300
# 8               20               auto                400
# 9               20               log2                200
# 10              20               log2                300
# 11              20               log2                400
# 12              30               auto                200
# 13              30               auto                300
# 14              30               auto                400
# 15              30               log2                200
# 16              30               log2                300
# 17              30               log2                400
#
#                                                params  split0_test_score  \
# 0   {'max_depth': 10, 'max_features': 'auto', 'n_e...           0.807215
# 1   {'max_depth': 10, 'max_features': 'auto', 'n_e...           0.807742
# 2   {'max_depth': 10, 'max_features': 'auto', 'n_e...           0.807787
# 3   {'max_depth': 10, 'max_features': 'log2', 'n_e...           0.788925
# 4   {'max_depth': 10, 'max_features': 'log2', 'n_e...           0.788306
# 5   {'max_depth': 10, 'max_features': 'log2', 'n_e...           0.788065
# 6   {'max_depth': 20, 'max_features': 'auto', 'n_e...           0.817239
# 7   {'max_depth': 20, 'max_features': 'auto', 'n_e...           0.817465
# 8   {'max_depth': 20, 'max_features': 'auto', 'n_e...           0.818384
# 9   {'max_depth': 20, 'max_features': 'log2', 'n_e...           0.818614
# 10  {'max_depth': 20, 'max_features': 'log2', 'n_e...           0.818486
# 11  {'max_depth': 20, 'max_features': 'log2', 'n_e...           0.818780
# 12  {'max_depth': 30, 'max_features': 'auto', 'n_e...           0.818044
# 13  {'max_depth': 30, 'max_features': 'auto', 'n_e...           0.818689
# 14  {'max_depth': 30, 'max_features': 'auto', 'n_e...           0.817686
# 15  {'max_depth': 30, 'max_features': 'log2', 'n_e...           0.818248
# 16  {'max_depth': 30, 'max_features': 'log2', 'n_e...           0.818424
# 17  {'max_depth': 30, 'max_features': 'log2', 'n_e...           0.819414
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.806337           0.812273           0.809717
# 1            0.806429           0.812217           0.809568
# 2            0.806370           0.811988           0.809237
# 3            0.779162           0.790896           0.787118
# 4            0.783243           0.791587           0.786541
# 5            0.781081           0.791611           0.787664
# 6            0.818848           0.822230           0.819861
# 7            0.818839           0.822477           0.819762
# 8            0.818917           0.822829           0.820945
# 9            0.816884           0.822607           0.819132
# 10           0.817406           0.823104           0.820211
# 11           0.817756           0.823109           0.819892
# 12           0.819005           0.822487           0.820121
# 13           0.819114           0.822083           0.821042
# 14           0.818879           0.822367           0.820237
# 15           0.817073           0.822849           0.819049
# 16           0.817784           0.823424           0.820573
# 17           0.817923           0.823754           0.819874
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.799581         0.807025        0.004259               15
# 1            0.799450         0.807081        0.004281               13
# 2            0.799846         0.807046        0.004051               14
# 3            0.777367         0.784693        0.005414               18
# 4            0.779761         0.785888        0.004081               16
# 5            0.777622         0.785209        0.005094               17
# 6            0.808916         0.817419        0.004550               10
# 7            0.808890         0.817487        0.004600                9
# 8            0.809737         0.818162        0.004497                2
# 9            0.808821         0.817212        0.004589               12
# 10           0.809974         0.817836        0.004378                5
# 11           0.809392         0.817786        0.004565                6
# 12           0.808847         0.817701        0.004669                8
# 13           0.808725         0.817930        0.004767                4
# 14           0.809646         0.817763        0.004347                7
# 15           0.809802         0.817404        0.004265               11
# 16           0.809842         0.818009        0.004535                3
# 17           0.810761         0.818345        0.004253                1

# %% [markdown]
# # Conclusion
# The best R^2 we get is 0.818 which is Very Good estimation for Income. The model is RandomForestRegressor.
